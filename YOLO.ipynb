# %%
from ultralytics import YOLO
import cv2
import numpy as np
import json
from moviepy.editor import VideoFileClip
import os  # Импортируем модуль os для работы с файловой системой

class VideoObjectDetection:
    def __init__(self, video_path, conf_threshold=0.5, tracked_classes=None):
        self.video_path = video_path
        self.model = YOLO("yolov10x.pt")
        self.conf_threshold = conf_threshold  

        # Список классов модели YOLO
        self.class_names = [
            "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train",
            "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter",
            "bench", "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear",
            "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", 
            "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
            "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle",
            "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
            "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut",
            "cake", "chair", "couch", "potted plant", "bed", "dining table", "toilet",
            "TV", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave",
            "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase",
            "scissors", "teddy bear", "hair drier", "toothbrush"
        ]

        # Список классов для отслеживания
        self.tracked_classes = tracked_classes if tracked_classes else self.class_names
        self.detections_data = []  # Для сохранения информации об объектах

    def get_contrast_color(self, background_color):
        """Возвращает черный или белый цвет в зависимости от яркости фона."""
        brightness = np.mean(background_color)
        return (255, 255, 255) if brightness < 128 else (0, 0, 0)

    def process_video(self, output_video_path="output_with_detections.mp4", json_output_path="detections.json"):
        cap = cv2.VideoCapture(self.video_path)

        if not cap.isOpened():
            print("Ошибка: не удалось открыть видео.")
            return

        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        frame_count = 0  # Счётчик кадров

        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        temp_output_path = "temp_output.mp4"
        out = cv2.VideoWriter(temp_output_path, fourcc, fps, (frame_width, frame_height))

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_count += 1  # Увеличиваем номер кадра
            results = self.model(frame)

            det = results[0]
            pred = det.boxes.xyxy.cpu().numpy() 
            classes = det.boxes.cls.cpu().numpy()  
            confs = det.boxes.conf.cpu().numpy() 

            frame_detections = []  # Список объектов на текущем кадре

            for box, cls, conf in zip(pred, classes, confs):
                if conf < self.conf_threshold:
                    continue 
                
                class_name = self.class_names[int(cls)]
                
                if class_name not in self.tracked_classes:
                    continue

                x1, y1, x2, y2 = box
                label = f"{class_name} ({conf:.2f})" 

                # Добавление информации о детекции в список
                frame_detections.append({
                    "class": class_name,
                    "confidence": float(conf),
                    "bbox": [int(x1), int(y1), int(x2), int(y2)]
                })

                background_color = cv2.mean(frame[int(y1):int(y2), int(x1):int(x2)])[0:3]
                text_color = self.get_contrast_color(background_color)

                # Проверка выхода текста за границы кадра
                (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)
                y_text = int(y1) - 10

                # Смещение текста вверх, если он выходит за верхнюю границу кадра
                if y_text - text_height < 0:
                    y_text = int(y1) + text_height + 10

                # Убедимся, что текст не выходит за правую границу кадра
                if int(x1) + text_width > frame_width:
                    x1 = frame_width - text_width - 10

                cv2.putText(frame, label, (int(x1), y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 2)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

            # Сохранение детекций текущего кадра
            if frame_detections:
                timestamp = frame_count / fps  # Вычисление таймкода в секундах
                self.detections_data.append({
                    "frame": frame_count,
                    "timestamp": round(timestamp, 2),  # Округляем до двух знаков после запятой
                    "detections": frame_detections
                })

            out.write(frame)
            cv2.imshow('Frame with Detections', frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        out.release()
        cv2.destroyAllWindows()

        # Сохранение данных о детекциях в JSON файл
        with open(json_output_path, 'w') as f:
            json.dump(self.detections_data, f, indent=4)

        # Добавление аудио к видео
        video_clip = VideoFileClip(temp_output_path)
        original_audio = VideoFileClip(self.video_path).audio
        video_with_audio = video_clip.set_audio(original_audio)

        video_with_audio.write_videofile(output_video_path, codec="libx264", audio_codec="aac")

        print(f"Видео с детекциями и аудио сохранено как {output_video_path}")
        print(f"Детекции сохранены в файл {json_output_path}")

        # Удаляем временный файл
        if os.path.exists(temp_output_path):
            os.remove(temp_output_path)
            print(f"Временный файл {temp_output_path} был удалён.")

class VideoPlayer:
    def __init__(self, video_path, tracked_classes, conf_threshold=0.5):
        self.video_path = video_path
        self.tracked_classes = tracked_classes
        self.conf_threshold = conf_threshold
        self.detector = VideoObjectDetection(video_path, conf_threshold, tracked_classes)

    def play_video_with_detections(self, output_video_path="output_with_detections.mp4", json_output_path="detections.json"):
        self.detector.process_video(output_video_path=output_video_path, json_output_path=json_output_path)


# Пример использования:
video_path = "Pixel_2.mp4"

# "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train",
# "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter",
# "bench", "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear",
# "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", 
# "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
# "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle",
# "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
# "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut",
# "cake", "chair", "couch", "potted plant", "bed", "dining table", "toilet",
# "TV", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave",
# "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase",
# "scissors", "teddy bear", "hair drier", "toothbrush"


# Указываем конкретные классы для отслеживания
tracked_classes = [
            "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train",
            "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter",
            "bench", "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear",
            "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", 
            "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
            "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle",
            "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
            "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut",
            "cake", "chair", "couch", "potted plant", "bed", "dining table", "toilet",
            "TV", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave",
            "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase",
            "scissors", "teddy bear", "hair drier", "toothbrush"
        ]

num_conf_threshold = 0.6
output_video_file = "output_Pixel_2.mp4"  # Укажите имя выходного видео файла
output_json_file = "output_Pixel_2.json"  # Укажите имя выходного JSON файла

video_player = VideoPlayer(video_path, tracked_classes, num_conf_threshold)
video_player.play_video_with_detections(output_video_path=output_video_file, json_output_path=output_json_file)
# Out:
# 0: 320x640 1 person, 249.5ms
# Speed: 1.0ms preprocess, 249.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.8ms
# Speed: 1.0ms preprocess, 248.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 242.2ms
# Speed: 1.0ms preprocess, 242.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 255.1ms
# Speed: 1.0ms preprocess, 255.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 244.6ms
# Speed: 1.0ms preprocess, 244.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 246.8ms
# Speed: 2.5ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 243.2ms
# Speed: 1.1ms preprocess, 243.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 246.0ms
# Speed: 1.0ms preprocess, 246.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 243.7ms
# Speed: 1.0ms preprocess, 243.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 cell phone, 241.4ms
# Speed: 1.5ms preprocess, 241.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 cell phone, 245.0ms
# Speed: 1.0ms preprocess, 245.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 cell phone, 247.6ms
# Speed: 1.0ms preprocess, 247.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 cell phone, 246.8ms
# Speed: 1.0ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 remote, 1 cell phone, 245.2ms
# Speed: 2.0ms preprocess, 245.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 remote, 1 cell phone, 244.8ms
# Speed: 1.0ms preprocess, 244.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 remote, 244.9ms
# Speed: 1.0ms preprocess, 244.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 potted plant, 1 remote, 245.3ms
# Speed: 1.3ms preprocess, 245.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.0ms
# Speed: 1.0ms preprocess, 246.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.4ms
# Speed: 1.0ms preprocess, 246.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 247.1ms
# Speed: 1.0ms preprocess, 247.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.1ms
# Speed: 1.0ms preprocess, 245.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.2ms
# Speed: 1.0ms preprocess, 246.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.8ms
# Speed: 1.1ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 1 cell phone, 248.9ms
# Speed: 0.0ms preprocess, 248.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 247.0ms
# Speed: 1.0ms preprocess, 247.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 247.2ms
# Speed: 3.0ms preprocess, 247.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 246.7ms
# Speed: 0.0ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 244.9ms
# Speed: 2.5ms preprocess, 244.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.9ms
# Speed: 0.0ms preprocess, 246.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 247.5ms
# Speed: 0.0ms preprocess, 247.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.3ms
# Speed: 1.4ms preprocess, 245.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 245.9ms
# Speed: 1.1ms preprocess, 245.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.4ms
# Speed: 0.0ms preprocess, 246.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.4ms
# Speed: 1.0ms preprocess, 246.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.2ms
# Speed: 1.0ms preprocess, 246.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.5ms
# Speed: 1.0ms preprocess, 245.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.8ms
# Speed: 1.0ms preprocess, 245.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 247.1ms
# Speed: 1.0ms preprocess, 247.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 248.6ms
# Speed: 0.0ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.3ms
# Speed: 1.0ms preprocess, 246.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 248.0ms
# Speed: 1.0ms preprocess, 248.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.1ms
# Speed: 1.0ms preprocess, 245.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 244.3ms
# Speed: 1.0ms preprocess, 244.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.0ms
# Speed: 1.0ms preprocess, 245.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.3ms
# Speed: 1.5ms preprocess, 245.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 245.9ms
# Speed: 1.0ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.4ms
# Speed: 1.0ms preprocess, 246.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 248.1ms
# Speed: 0.0ms preprocess, 248.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 245.6ms
# Speed: 1.0ms preprocess, 245.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.8ms
# Speed: 1.0ms preprocess, 246.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 246.0ms
# Speed: 1.0ms preprocess, 246.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 1 cell phone, 246.2ms
# Speed: 1.0ms preprocess, 246.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 246.9ms
# Speed: 1.0ms preprocess, 246.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 1 cell phone, 246.7ms
# Speed: 1.0ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 249.0ms
# Speed: 1.0ms preprocess, 249.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 246.9ms
# Speed: 1.5ms preprocess, 246.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 244.9ms
# Speed: 1.5ms preprocess, 244.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 246.4ms
# Speed: 1.0ms preprocess, 246.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 244.8ms
# Speed: 3.0ms preprocess, 244.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.3ms
# Speed: 1.0ms preprocess, 245.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 245.6ms
# Speed: 1.0ms preprocess, 245.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 246.1ms
# Speed: 1.0ms preprocess, 246.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 245.5ms
# Speed: 1.5ms preprocess, 245.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 246.3ms
# Speed: 1.0ms preprocess, 246.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bottle, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 246.7ms
# Speed: 1.0ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 246.0ms
# Speed: 1.5ms preprocess, 246.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 248.2ms
# Speed: 1.0ms preprocess, 248.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 247.5ms
# Speed: 1.0ms preprocess, 247.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 2 cell phones, 1 refrigerator, 247.7ms
# Speed: 1.0ms preprocess, 247.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 245.9ms
# Speed: 1.0ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 244.8ms
# Speed: 1.0ms preprocess, 244.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 2 cell phones, 1 refrigerator, 245.9ms
# Speed: 1.0ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 244.3ms
# Speed: 1.0ms preprocess, 244.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 refrigerator, 245.4ms
# Speed: 1.0ms preprocess, 245.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 refrigerator, 245.1ms
# Speed: 1.0ms preprocess, 245.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 refrigerator, 247.1ms
# Speed: 1.0ms preprocess, 247.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 1 refrigerator, 246.3ms
# Speed: 1.0ms preprocess, 246.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 2 cell phones, 1 refrigerator, 246.5ms
# Speed: 1.0ms preprocess, 246.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 2 cell phones, 1 refrigerator, 246.1ms
# Speed: 1.0ms preprocess, 246.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 247.7ms
# Speed: 1.0ms preprocess, 247.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 246.9ms
# Speed: 1.0ms preprocess, 246.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 248.2ms
# Speed: 0.0ms preprocess, 248.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 248.7ms
# Speed: 1.0ms preprocess, 248.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 248.0ms
# Speed: 1.0ms preprocess, 248.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 249.9ms
# Speed: 1.0ms preprocess, 249.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 1 refrigerator, 247.5ms
# Speed: 1.0ms preprocess, 247.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 1 refrigerator, 244.4ms
# Speed: 1.0ms preprocess, 244.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 244.2ms
# Speed: 1.0ms preprocess, 244.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.1ms
# Speed: 1.0ms preprocess, 246.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.7ms
# Speed: 1.1ms preprocess, 245.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 244.0ms
# Speed: 1.0ms preprocess, 244.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.2ms
# Speed: 1.0ms preprocess, 245.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.6ms
# Speed: 1.5ms preprocess, 245.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 244.8ms
# Speed: 1.0ms preprocess, 244.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.8ms
# Speed: 1.0ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 247.6ms
# Speed: 1.0ms preprocess, 247.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.4ms
# Speed: 1.0ms preprocess, 245.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.3ms
# Speed: 1.0ms preprocess, 248.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 249.1ms
# Speed: 1.0ms preprocess, 249.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 246.5ms
# Speed: 1.0ms preprocess, 246.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 246.0ms
# Speed: 1.0ms preprocess, 246.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 245.9ms
# Speed: 0.0ms preprocess, 245.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 244.4ms
# Speed: 2.0ms preprocess, 244.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.1ms
# Speed: 1.0ms preprocess, 248.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.2ms
# Speed: 0.0ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.6ms
# Speed: 1.1ms preprocess, 246.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 251.2ms
# Speed: 2.5ms preprocess, 251.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 252.4ms
# Speed: 1.0ms preprocess, 252.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.1ms
# Speed: 1.0ms preprocess, 248.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 249.1ms
# Speed: 1.0ms preprocess, 249.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 254.0ms
# Speed: 1.0ms preprocess, 254.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 249.2ms
# Speed: 2.0ms preprocess, 249.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 262.1ms
# Speed: 1.0ms preprocess, 262.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 252.7ms
# Speed: 0.0ms preprocess, 252.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 248.7ms
# Speed: 1.0ms preprocess, 248.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.1ms
# Speed: 1.0ms preprocess, 246.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 247.4ms
# Speed: 1.0ms preprocess, 247.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.4ms
# Speed: 1.0ms preprocess, 248.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.4ms
# Speed: 1.0ms preprocess, 248.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 248.2ms
# Speed: 1.5ms preprocess, 248.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 251.7ms
# Speed: 1.0ms preprocess, 251.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 270.9ms
# Speed: 1.0ms preprocess, 270.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.2ms
# Speed: 1.0ms preprocess, 246.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.4ms
# Speed: 1.0ms preprocess, 242.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.8ms
# Speed: 1.0ms preprocess, 242.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.8ms
# Speed: 1.0ms preprocess, 242.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 240.8ms
# Speed: 1.0ms preprocess, 240.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.6ms
# Speed: 0.0ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.3ms
# Speed: 1.5ms preprocess, 246.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 252.1ms
# Speed: 1.0ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.8ms
# Speed: 1.0ms preprocess, 248.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 247.4ms
# Speed: 1.0ms preprocess, 247.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 252.0ms
# Speed: 1.0ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 251.0ms
# Speed: 1.0ms preprocess, 251.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.5ms
# Speed: 1.0ms preprocess, 248.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 249.7ms
# Speed: 1.0ms preprocess, 249.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 253.4ms
# Speed: 1.0ms preprocess, 253.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 256.1ms
# Speed: 1.0ms preprocess, 256.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 251.2ms
# Speed: 1.5ms preprocess, 251.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 250.0ms
# Speed: 1.0ms preprocess, 250.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 261.4ms
# Speed: 0.0ms preprocess, 261.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.3ms
# Speed: 1.0ms preprocess, 248.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 249.4ms
# Speed: 1.0ms preprocess, 249.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 247.5ms
# Speed: 1.0ms preprocess, 247.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.0ms
# Speed: 1.0ms preprocess, 245.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 244.7ms
# Speed: 1.0ms preprocess, 244.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 243.4ms
# Speed: 1.0ms preprocess, 243.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 239.4ms
# Speed: 1.0ms preprocess, 239.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.8ms
# Speed: 0.0ms preprocess, 242.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 243.8ms
# Speed: 1.0ms preprocess, 243.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 242.7ms
# Speed: 1.0ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 248.5ms
# Speed: 1.0ms preprocess, 248.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 247.7ms
# Speed: 1.0ms preprocess, 247.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 253.6ms
# Speed: 2.0ms preprocess, 253.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 253.5ms
# Speed: 1.0ms preprocess, 253.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 244.1ms
# Speed: 1.5ms preprocess, 244.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 268.2ms
# Speed: 1.0ms preprocess, 268.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 263.1ms
# Speed: 0.0ms preprocess, 263.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 263.1ms
# Speed: 1.0ms preprocess, 263.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 241.3ms
# Speed: 1.0ms preprocess, 241.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 240.3ms
# Speed: 2.0ms preprocess, 240.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 255.7ms
# Speed: 1.0ms preprocess, 255.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 245.1ms
# Speed: 0.0ms preprocess, 245.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 251.1ms
# Speed: 1.0ms preprocess, 251.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 254.9ms
# Speed: 1.0ms preprocess, 254.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 252.6ms
# Speed: 1.0ms preprocess, 252.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 259.2ms
# Speed: 1.0ms preprocess, 259.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 246.7ms
# Speed: 1.0ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 252.1ms
# Speed: 1.1ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 246.0ms
# Speed: 1.1ms preprocess, 246.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.7ms
# Speed: 1.0ms preprocess, 242.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.8ms
# Speed: 1.0ms preprocess, 266.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.0ms
# Speed: 2.0ms preprocess, 266.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 270.6ms
# Speed: 1.0ms preprocess, 270.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 265.4ms
# Speed: 1.0ms preprocess, 265.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 255.2ms
# Speed: 1.0ms preprocess, 255.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 264.0ms
# Speed: 1.0ms preprocess, 264.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 260.3ms
# Speed: 1.0ms preprocess, 260.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 255.9ms
# Speed: 1.0ms preprocess, 255.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 249.8ms
# Speed: 1.0ms preprocess, 249.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 257.0ms
# Speed: 0.0ms preprocess, 257.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 245.7ms
# Speed: 1.0ms preprocess, 245.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 250.0ms
# Speed: 1.0ms preprocess, 250.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 255.5ms
# Speed: 1.0ms preprocess, 255.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 257.2ms
# Speed: 1.1ms preprocess, 257.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 251.8ms
# Speed: 1.0ms preprocess, 251.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 245.7ms
# Speed: 1.0ms preprocess, 245.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 256.7ms
# Speed: 1.0ms preprocess, 256.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 248.4ms
# Speed: 1.0ms preprocess, 248.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 251.2ms
# Speed: 1.0ms preprocess, 251.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 252.3ms
# Speed: 1.0ms preprocess, 252.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.8ms
# Speed: 1.0ms preprocess, 243.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.5ms
# Speed: 0.5ms preprocess, 241.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 247.9ms
# Speed: 1.0ms preprocess, 247.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 256.1ms
# Speed: 1.0ms preprocess, 256.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 250.5ms
# Speed: 1.0ms preprocess, 250.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.3ms
# Speed: 1.0ms preprocess, 243.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.0ms
# Speed: 1.0ms preprocess, 242.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 246.9ms
# Speed: 0.0ms preprocess, 246.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.1ms
# Speed: 1.0ms preprocess, 243.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 245.3ms
# Speed: 1.0ms preprocess, 245.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.5ms
# Speed: 1.0ms preprocess, 243.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.1ms
# Speed: 1.5ms preprocess, 243.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 240.9ms
# Speed: 1.0ms preprocess, 240.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 240.8ms
# Speed: 2.0ms preprocess, 240.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.7ms
# Speed: 1.0ms preprocess, 241.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 240.7ms
# Speed: 1.0ms preprocess, 240.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.6ms
# Speed: 1.0ms preprocess, 241.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 240.8ms
# Speed: 1.2ms preprocess, 240.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 252.0ms
# Speed: 1.0ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 257.0ms
# Speed: 1.5ms preprocess, 257.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 259.6ms
# Speed: 2.2ms preprocess, 259.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 247.3ms
# Speed: 1.0ms preprocess, 247.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 264.1ms
# Speed: 1.0ms preprocess, 264.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 254.2ms
# Speed: 1.0ms preprocess, 254.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 265.1ms
# Speed: 1.5ms preprocess, 265.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 264.9ms
# Speed: 1.5ms preprocess, 264.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 260.0ms
# Speed: 1.0ms preprocess, 260.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 268.2ms
# Speed: 1.0ms preprocess, 268.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 260.8ms
# Speed: 1.5ms preprocess, 260.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 268.8ms
# Speed: 2.1ms preprocess, 268.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.7ms
# Speed: 1.0ms preprocess, 267.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 261.2ms
# Speed: 1.0ms preprocess, 261.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 remotes, 269.4ms
# Speed: 1.5ms preprocess, 269.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 remotes, 266.5ms
# Speed: 1.5ms preprocess, 266.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 remotes, 269.4ms
# Speed: 1.0ms preprocess, 269.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 remotes, 265.1ms
# Speed: 1.0ms preprocess, 265.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 255.6ms
# Speed: 1.0ms preprocess, 255.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 269.0ms
# Speed: 1.0ms preprocess, 269.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.5ms
# Speed: 2.1ms preprocess, 266.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.4ms
# Speed: 1.5ms preprocess, 267.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 269.2ms
# Speed: 1.0ms preprocess, 269.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 265.8ms
# Speed: 1.0ms preprocess, 265.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.4ms
# Speed: 1.0ms preprocess, 266.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 266.0ms
# Speed: 1.0ms preprocess, 266.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.1ms
# Speed: 1.0ms preprocess, 266.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.7ms
# Speed: 1.0ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.8ms
# Speed: 1.5ms preprocess, 241.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.5ms
# Speed: 1.0ms preprocess, 242.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.4ms
# Speed: 1.0ms preprocess, 242.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.6ms
# Speed: 1.5ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 260.8ms
# Speed: 1.0ms preprocess, 260.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 268.9ms
# Speed: 1.0ms preprocess, 268.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 cell phone, 267.9ms
# Speed: 1.0ms preprocess, 267.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 242.1ms
# Speed: 1.0ms preprocess, 242.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 1 cell phone, 263.0ms
# Speed: 1.1ms preprocess, 263.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 270.0ms
# Speed: 1.0ms preprocess, 270.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 268.7ms
# Speed: 1.0ms preprocess, 268.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 265.6ms
# Speed: 1.1ms preprocess, 265.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 269.4ms
# Speed: 1.0ms preprocess, 269.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 1 cell phone, 268.7ms
# Speed: 1.0ms preprocess, 268.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 1 cell phone, 259.7ms
# Speed: 1.0ms preprocess, 259.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 1 cell phone, 243.1ms
# Speed: 1.0ms preprocess, 243.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.4ms
# Speed: 1.0ms preprocess, 243.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 248.0ms
# Speed: 1.0ms preprocess, 248.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 269.7ms
# Speed: 2.0ms preprocess, 269.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.8ms
# Speed: 1.0ms preprocess, 267.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 249.8ms
# Speed: 1.0ms preprocess, 249.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.2ms
# Speed: 1.0ms preprocess, 243.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 246.5ms
# Speed: 1.0ms preprocess, 246.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 270.4ms
# Speed: 1.0ms preprocess, 270.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 249.8ms
# Speed: 0.0ms preprocess, 249.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 267.4ms
# Speed: 1.0ms preprocess, 267.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 266.7ms
# Speed: 1.0ms preprocess, 266.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 254.0ms
# Speed: 1.5ms preprocess, 254.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 258.9ms
# Speed: 1.0ms preprocess, 258.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 259.3ms
# Speed: 1.0ms preprocess, 259.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 248.3ms
# Speed: 1.0ms preprocess, 248.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 244.4ms
# Speed: 1.0ms preprocess, 244.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 245.4ms
# Speed: 0.0ms preprocess, 245.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 244.3ms
# Speed: 1.0ms preprocess, 244.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.8ms
# Speed: 1.5ms preprocess, 243.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.7ms
# Speed: 1.0ms preprocess, 243.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 249.1ms
# Speed: 1.0ms preprocess, 249.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 247.2ms
# Speed: 0.5ms preprocess, 247.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 243.8ms
# Speed: 1.0ms preprocess, 243.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 247.9ms
# Speed: 1.0ms preprocess, 247.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 248.9ms
# Speed: 1.0ms preprocess, 248.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 remote, 241.9ms
# Speed: 1.0ms preprocess, 241.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 refrigerator, 253.2ms
# Speed: 1.5ms preprocess, 253.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 249.0ms
# Speed: 2.0ms preprocess, 249.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 257.6ms
# Speed: 1.0ms preprocess, 257.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 refrigerator, 244.2ms
# Speed: 1.5ms preprocess, 244.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 243.5ms
# Speed: 1.0ms preprocess, 243.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 248.8ms
# Speed: 1.0ms preprocess, 248.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 245.4ms
# Speed: 1.0ms preprocess, 245.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 254.5ms
# Speed: 1.0ms preprocess, 254.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 1 refrigerator, 248.6ms
# Speed: 1.0ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 239.0ms
# Speed: 1.0ms preprocess, 239.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 240.0ms
# Speed: 0.0ms preprocess, 240.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 269.1ms
# Speed: 1.0ms preprocess, 269.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 266.9ms
# Speed: 1.0ms preprocess, 266.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 refrigerator, 256.5ms
# Speed: 1.0ms preprocess, 256.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 240.5ms
# Speed: 0.0ms preprocess, 240.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 238.6ms
# Speed: 1.5ms preprocess, 238.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 262.1ms
# Speed: 1.2ms preprocess, 262.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 245.8ms
# Speed: 1.0ms preprocess, 245.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.6ms
# Speed: 1.1ms preprocess, 245.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 235.0ms
# Speed: 1.0ms preprocess, 235.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.6ms
# Speed: 1.0ms preprocess, 245.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.3ms
# Speed: 1.5ms preprocess, 245.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 244.9ms
# Speed: 1.0ms preprocess, 244.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.5ms
# Speed: 1.0ms preprocess, 245.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.2ms
# Speed: 1.0ms preprocess, 242.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 261.8ms
# Speed: 1.0ms preprocess, 261.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 254.5ms
# Speed: 1.0ms preprocess, 254.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 245.4ms
# Speed: 1.5ms preprocess, 245.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.9ms
# Speed: 1.5ms preprocess, 245.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.0ms
# Speed: 1.0ms preprocess, 242.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 238.5ms
# Speed: 1.5ms preprocess, 238.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.0ms
# Speed: 1.0ms preprocess, 243.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.2ms
# Speed: 1.0ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.9ms
# Speed: 1.5ms preprocess, 242.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.3ms
# Speed: 1.0ms preprocess, 245.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.8ms
# Speed: 1.0ms preprocess, 243.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 244.1ms
# Speed: 1.5ms preprocess, 244.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.4ms
# Speed: 1.0ms preprocess, 243.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.6ms
# Speed: 1.0ms preprocess, 243.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.6ms
# Speed: 1.0ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.8ms
# Speed: 1.0ms preprocess, 242.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.3ms
# Speed: 1.0ms preprocess, 242.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.3ms
# Speed: 1.0ms preprocess, 241.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.8ms
# Speed: 1.0ms preprocess, 239.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.3ms
# Speed: 1.0ms preprocess, 241.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 240.9ms
# Speed: 1.0ms preprocess, 240.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 242.2ms
# Speed: 0.0ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 remote, 1 cell phone, 239.2ms
# Speed: 1.0ms preprocess, 239.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 240.6ms
# Speed: 1.0ms preprocess, 240.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 238.2ms
# Speed: 1.0ms preprocess, 238.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.2ms
# Speed: 1.5ms preprocess, 239.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.8ms
# Speed: 1.0ms preprocess, 239.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 243.2ms
# Speed: 2.0ms preprocess, 243.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 242.0ms
# Speed: 1.0ms preprocess, 242.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 242.1ms
# Speed: 1.0ms preprocess, 242.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 239.4ms
# Speed: 0.5ms preprocess, 239.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 1 cell phone, 240.7ms
# Speed: 1.0ms preprocess, 240.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 remote, 238.6ms
# Speed: 1.0ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 241.5ms
# Speed: 1.0ms preprocess, 241.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 240.4ms
# Speed: 1.0ms preprocess, 240.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.4ms
# Speed: 1.0ms preprocess, 241.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 240.4ms
# Speed: 0.0ms preprocess, 240.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.9ms
# Speed: 1.0ms preprocess, 241.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 potted plant, 1 cell phone, 242.8ms
# Speed: 1.5ms preprocess, 242.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.1ms
# Speed: 0.0ms preprocess, 241.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.3ms
# Speed: 1.0ms preprocess, 242.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.3ms
# Speed: 1.0ms preprocess, 242.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.5ms
# Speed: 1.0ms preprocess, 241.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.2ms
# Speed: 1.5ms preprocess, 241.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 240.0ms
# Speed: 0.0ms preprocess, 240.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.0ms
# Speed: 0.0ms preprocess, 239.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.7ms
# Speed: 1.0ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 231.3ms
# Speed: 0.0ms preprocess, 231.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.5ms
# Speed: 1.0ms preprocess, 243.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 243.5ms
# Speed: 1.0ms preprocess, 243.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 248.6ms
# Speed: 1.5ms preprocess, 248.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.2ms
# Speed: 1.0ms preprocess, 242.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 244.2ms
# Speed: 1.0ms preprocess, 244.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 245.2ms
# Speed: 2.5ms preprocess, 245.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 241.0ms
# Speed: 1.0ms preprocess, 241.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.0ms
# Speed: 1.0ms preprocess, 239.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 239.5ms
# Speed: 1.0ms preprocess, 239.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 bowl, 1 chair, 1 potted plant, 1 cell phone, 242.7ms
# Speed: 1.0ms preprocess, 242.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Moviepy - Building video output_Pixel_2.mp4.
# MoviePy - Writing audio in output_Pixel_2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output_Pixel_2.mp4
# Moviepy - Done !
# Moviepy - video ready output_Pixel_2.mp4
# Видео с детекциями и аудио сохранено как output_Pixel_2.mp4
# Детекции сохранены в файл output_Pixel_2.json
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 194
#     191 output_json_file = "output_Pixel_2.json"  # Укажите имя выходного JSON файла
#     193 video_player = VideoPlayer(video_path, tracked_classes, num_conf_threshold)
# --> 194 video_player.play_video_with_detections(output_video_path=output_video_file, json_output_path=output_json_file)
#
# Cell In[13], line 153, in VideoPlayer.play_video_with_detections(self, output_video_path, json_output_path)
#     152 def play_video_with_detections(self, output_video_path="output_with_detections.mp4", json_output_path="detections.json"):
# --> 153     self.detector.process_video(output_video_path=output_video_path, json_output_path=json_output_path)
#
# Cell In[13], line 142, in VideoObjectDetection.process_video(self, output_video_path, json_output_path)
#     140 # Удаляем временный файл
#     141 if os.path.exists(temp_output_path):
# --> 142     os.remove(temp_output_path)
#     143     print(f"Временный файл {temp_output_path} был удалён.")
#
# PermissionError: [WinError 32] Процесс не может получить доступ к файлу, так как этот файл занят другим процессом: 'temp_output.mp4'

# %%
import cv2
import json

class VideoFrameExtractor:
    def __init__(self, video_path, json_path, tracked_classes):
        self.video_path = video_path
        self.json_path = json_path
        self.tracked_classes = tracked_classes

    def extract_frames(self):
        # Загружаем данные из JSON файла
        with open(self.json_path, 'r') as f:
            detections_data = json.load(f)

        # Открываем видео
        cap = cv2.VideoCapture(self.video_path)

        if not cap.isOpened():
            print("Ошибка: не удалось открыть видео.")
            return

        frame_count = 0  # Счётчик кадров

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_count += 1  # Увеличиваем номер кадра

            # Проверяем, есть ли детекции для текущего кадра
            for detection in detections_data:
                if detection["frame"] == frame_count:
                    for obj in detection["detections"]:
                        if obj["class"] in self.tracked_classes:
                            # Отображаем кадр, если обнаружен нужный класс
                            cv2.imshow(f'Frame with {obj["class"]}', frame)

                            # Ждем нажатия клавиши, чтобы закрыть окно
                            if cv2.waitKey(0) & 0xFF == ord('q'):
                                break

        cap.release()
        cv2.destroyAllWindows()

# Пример использования:
video_path = "output_Pixel_2.mp4"
json_path = "output_Pixel_2.json"
tracked_classes = ["person", "car", "dog", "cell phone"]  # Указываем классы, которые нужно отслеживать

frame_extractor = VideoFrameExtractor(video_path, json_path, tracked_classes)
frame_extractor.extract_frames()
